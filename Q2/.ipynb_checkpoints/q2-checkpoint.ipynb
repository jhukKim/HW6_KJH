# %%
import csv
import matplotlib.pyplot as plt

num=[1,2,3,4,5,6]

f=open('q2.csv')
data=csv.reader(f)


for row in data:
    arr=[]
    for i in range(6):
        arr.append(int(row[i]))     
    plt.plot(num,arr)
    plt.show()
    
f.close()
